# %%
import os

import pandas as pd
import requests
from dotenv import load_dotenv

# %%
load_dotenv() #this gets the API key from .env file so we can use it.
API_KEY = os.getenv("API_KEY")

# %% [markdown]
# <p>Here, we're making an events API call to TicketMaster and querying music events in New York City <br>
# for the time period of May 1, 2025 to Dec 31, 2027 just to make sure that we are able to pull up sufficient data.<br>
# Then checking for successful status code for the API call that confirms our setup is correct. <br>
# We then retrieve the response data back as a JSON so that we can work with this data format.</p>

# %%
events_url = f'https://app.ticketmaster.com/discovery/v2/events.json?apikey={API_KEY}'

# %%
events_params_action_api = {
    'startDateTime': '2025-05-01T18:00:00-05:00',
    'endDateTime': '2027-12-31T17:00:00-05:00',
    'classificationName': 'music',
    'dmaId': '345', 
    'city': 'New York',
    'size': '20', 
    'page': '5'
}

# %%
r = requests.get(events_url, params=events_params_action_api)
print(r.status_code)
data=r.json()
# Out:
# 200

# %%
# with open('output.txt', 'wt') as f:
#     print(data, file=f)

# %%
print(data.keys())
# Out:
# dict_keys(['_embedded', '_links', 'page'])

# %%
print(data['page'])
# Out:
# {'size': 20, 'totalElements': 722, 'totalPages': 37, 'number': 5}

# %%
print(len(data['_embedded']['events']))
# Out:
# 20

# %%
print(data)
# Out:
# {'_embedded': {'events': [{'name': 'Alabama Shakes', 'type': 'event', 'id': 'G5dYZ_F-Hysua', 'test': False, 'url': 'https://www.ticketmaster.com/alabama-shakes-new-york-new-york-09-02-2026/event/3C0064887CE71349', 'locale': 'en-us', 'images': [{'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_SOURCE', 'width': 2426, 'height': 1728, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_RETINA_LANDSCAPE_16_9.jpg', 'width': 1136, 'height': 639, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_RETINA_PORTRAIT_16_9.jpg', 'width': 640, 'height': 360, 'fallback': False}, {'ratio': '16_9', 'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_TABLET_LANDSCAPE_LARGE_16_9.jpg', 'width': 2048, 'height': 1152, 'fallback': False}, {'ratio': '3_2', 'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf1
# ...

# %% [markdown]
# #### **API Interpretation** ####
# <p> TicketMaster offers several APIs including Discovery (Public), Partner and Presence. <br>
# We opted with Public API as this was the only suitable option for our case. However, one drawback is that it <br>
# offers less visibility towards the company operations. We were initially looking to pull information on <br>
# the pricing structure. According to this [Reddit](https://www.reddit.com/r/programming/comments/10dxaiz/ticketmaster_stubhub_etc_inventory_via_api/) link, ticket platforms such as TicketMaster and Stubhub
# would be very unlikely to release coveted information related to their pricing as this would give its competitors an outside edge.
#
# Despite this setback, another possible next step, could be making another events API call to compare genre music preference of <br>
# another city to see how they compared in popularity.
#
# </p>

# %%
# print(data['_embedded']['events'])

# %%
data['_embedded']['events']
# Out:
# [{'name': 'Alabama Shakes',
#   'type': 'event',
#   'id': 'G5dYZ_F-Hysua',
#   'test': False,
#   'url': 'https://www.ticketmaster.com/alabama-shakes-new-york-new-york-09-02-2026/event/3C0064887CE71349',
#   'locale': 'en-us',
#   'images': [{'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_SOURCE',
#     'width': 2426,
#     'height': 1728,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_RETINA_LANDSCAPE_16_9.jpg',
#     'width': 1136,
#     'height': 639,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_RETINA_PORTRAIT_16_9.jpg',
#     'width': 640,
#     'height': 360,
#     'fallback': False},
#    {'ratio': '16_9',
#     'url': 'https://s1.ticketm.net/dam/a/359/ad509b7f-2b54-407f-9d04-9dbbf11fb359_TABLET_LANDSCAPE_LARGE_16_9.jpg',
#     'width': 2048,
#     'height': 1152,
# ...

# %% [markdown]
# ### Creating initial dataframe for data exploration ###
# This dataframe gives us 20 row view

# %%
df = pd.DataFrame(data['_embedded']['events'])
df
# Out:
#                                                  name   type             id  \
# 0                                      Alabama Shakes  event  G5dYZ_F-Hysua
# 1                    YUNGBLUD: IDOLS - THE WORLD TOUR  event  G5dYZbVkK6OTg
# 2           Khalid: It's Always Summer Somewhere Tour  event  G5dYZbzhrO0M1
# 3                    Jessie Ware: The Superbloom Tour  event  G5dYZ_kma1OTc
# 4                     Mon Laferte - Femme Fatale Tour  event  G5dYZ_kppZOWi
# 5   The Format - 20 Years of Dog Problems + New & ...  event  G5dYZ_1NSz3fJ
# 6   The Human League With Very Special Guests Soft...  event  G5dYZ_eBH0oca
# 7                  Shaboozey - Outlaws Never Die Tour  event  G5dYZ_aJgQsbY
# 8            Ricardo Montaner: El Último Regreso Tour  event  G5dYZbUCqm3ey
# 9                Ella Mai: Do You Still Love Me? Tour  event  G5dYZ_kh9-o_2
# 10    CA7RIEL & Paco Amoroso: FREE SPIRITS WORLD TOUR  event  G5dYZ_69VFek3
# ...

# %% [markdown]
# <p> Looking at the 20 rows of data with <code>df.info</code>, we see that all the columns are populated with some values.
# It does not appear that we have any missing data at this point.</p>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             20 non-null     str
#  1   type             20 non-null     str
#  2   id               20 non-null     str
#  3   test             20 non-null     bool
#  4   url              20 non-null     str
#  5   locale           20 non-null     str
#  6   images           20 non-null     object
#  7   sales            20 non-null     object
#  8   dates            20 non-null     object
#  9   classifications  20 non-null     object
#  10  promoter         20 non-null     object
#  11  promoters        20 non-null     object
#  12  info             20 non-null     str
#  13  pleaseNote       20 non-null     str
#  14  products         20 non-null     object
#  15  seatmap          20 non-null     object
#  16  accessibility    20 non-null     object
# ...

# %% [markdown]
# #### Some columns in the Dataframe are not in a usable state. So, I'm starting to set the stage to start looping within `Accessibility`, `Products`, `Classifications` and `Venue` name. ####

# %%
accessibility = df['accessibility']
accessibility.iloc[13]
# Out:
# {'ticketLimit': 4}

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             20 non-null     str
#  1   type             20 non-null     str
#  2   id               20 non-null     str
#  3   test             20 non-null     bool
#  4   url              20 non-null     str
#  5   locale           20 non-null     str
#  6   images           20 non-null     object
#  7   sales            20 non-null     object
#  8   dates            20 non-null     object
#  9   classifications  20 non-null     object
#  10  promoter         20 non-null     object
#  11  promoters        20 non-null     object
#  12  info             20 non-null     str
#  13  pleaseNote       20 non-null     str
#  14  products         20 non-null     object
#  15  seatmap          20 non-null     object
#  16  accessibility    20 non-null     object
# ...

# %% [markdown]
# ### For-loop to grab the value of Accessibility in nested dictionary encased in a list ###

# %%
for item in accessibility:
    for location, value in item.items():
        print(f'Ticket Limit: ',value)
# Out:
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  2
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4
# Ticket Limit:  4

# %% [markdown]
# ### Creating variable to refer to 'products' column ###

# %%
product_name = df['products']

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             20 non-null     str
#  1   type             20 non-null     str
#  2   id               20 non-null     str
#  3   test             20 non-null     bool
#  4   url              20 non-null     str
#  5   locale           20 non-null     str
#  6   images           20 non-null     object
#  7   sales            20 non-null     object
#  8   dates            20 non-null     object
#  9   classifications  20 non-null     object
#  10  promoter         20 non-null     object
#  11  promoters        20 non-null     object
#  12  info             20 non-null     str
#  13  pleaseNote       20 non-null     str
#  14  products         20 non-null     object
#  15  seatmap          20 non-null     object
#  16  accessibility    20 non-null     object
# ...

# %% [markdown]
# ### Creating for loop to grab value of PRODUCTS column ###

# %%
for item in product_name:
    for n in item:
        print(n['name'])
# Out:
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO RADIO CITY MUSIC HALL
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE
# SatchVai Band VIP Upgrade Experience (No Ticket Included)
# SPOTHERO BEACON THEATRE
# SPOTHERO BEACON THEATRE

# %% [markdown]
# ### Re-assigning the output of above for-loop to PRODUCTS column to reflect new changes. ###

# %%
df['products'] = n['name']

# %% [markdown]
# ### List comprehension using for loop and re-assigning value to Accessibility column ###

# %%
df['accessibility'] = [f'Ticket Limit: {value}'
                       for item in accessibility
                        for location, value in item.items()]

# list comprehension to loop the 'accessibility' column to get Ticket Limit dictionary.

# %% [markdown]
# ##### Renaming columns to something that is more meaningful #####

# %%
df.rename(columns={
    '_embedded': 'Venue Name', 
    'name': 'Name',
    'type': 'Type', 
    'id': 'ID',
    'products': 'PRODUCTS', 
    'accessibility': 'Accessibility',
    'classifications': 'Genre'

    }, inplace=True)

# %%
df
# Out:
#                                                  Name   Type             ID  \
# 0                                      Alabama Shakes  event  G5dYZ_F-Hysua
# 1                    YUNGBLUD: IDOLS - THE WORLD TOUR  event  G5dYZbVkK6OTg
# 2           Khalid: It's Always Summer Somewhere Tour  event  G5dYZbzhrO0M1
# 3                    Jessie Ware: The Superbloom Tour  event  G5dYZ_kma1OTc
# 4                     Mon Laferte - Femme Fatale Tour  event  G5dYZ_kppZOWi
# 5   The Format - 20 Years of Dog Problems + New & ...  event  G5dYZ_1NSz3fJ
# 6   The Human League With Very Special Guests Soft...  event  G5dYZ_eBH0oca
# 7                  Shaboozey - Outlaws Never Die Tour  event  G5dYZ_aJgQsbY
# 8            Ricardo Montaner: El Último Regreso Tour  event  G5dYZbUCqm3ey
# 9                Ella Mai: Do You Still Love Me? Tour  event  G5dYZ_kh9-o_2
# 10    CA7RIEL & Paco Amoroso: FREE SPIRITS WORLD TOUR  event  G5dYZ_69VFek3
# ...

# %% [markdown]
# #### Creating variable to 'Genre' column ####

# %%
genre = df['Genre']
genre
# Out:
# 0     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 1     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 2     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 3     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 4     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 5     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 6     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 7     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 8     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 9     [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 10    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 11    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 12    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 13    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 14    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 15    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# 16    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# ...

# %% [markdown]
# #### For loop to pull Genre name out of dictionary list ####

# %%
for x in genre: #x is the dictionary
    for item in x:
        print(item['genre']['name']) #loop through Genre list to pull Genre name.
# Out:
# Rock
# Rock
# R&B
# Rock
# Pop
# Rock
# Rock
# Country
# Latin
# R&B
# Latin
# Rock
# Rock
# Rock
# Country
# Country
# Rock
# Rock
# Rock
# Rock

# %% [markdown]
# #### list comprehension using for loop and re-assigning the value to 'Genre' column ####

# %%
df['Genre'] = [item['genre']['name'] 
                for x in genre
                for item in x]

# %% [markdown]
# #### Creating variable for 'Venue Name' ####

# %%
venue_name = df['Venue Name']

# %% [markdown]
# #### For loop to grab the venue name from dictionary in a list ####

# %%
for x in venue_name: # to loop through Venue Name
    for y in x['venues']:
        print(y['name'])
# Out:
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Radio City Music Hall
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre
# Beacon Theatre

# %% [markdown]
# #### List comprehension using for loop and reassigning the value back to 'Venue Name' column. ####

# %%
df['Venue Name'] = [y['name'] 
                    for x in venue_name
                    for y in x['venues']]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             20 non-null     str
#  1   Type             20 non-null     str
#  2   ID               20 non-null     str
#  3   test             20 non-null     bool
#  4   url              20 non-null     str
#  5   locale           20 non-null     str
#  6   images           20 non-null     object
#  7   sales            20 non-null     object
#  8   dates            20 non-null     object
#  9   Genre            20 non-null     str
#  10  promoter         20 non-null     object
#  11  promoters        20 non-null     object
#  12  info             20 non-null     str
#  13  pleaseNote       20 non-null     str
#  14  PRODUCTS         20 non-null     str
#  15  seatmap          20 non-null     object
#  16  Accessibility    20 non-null     str
# ...

# %% [markdown]
# ##### Pagination Function #####
# <p>Here, we're implementing a function <code>getAllPages()</code> for pagination, in order to retrieve additional pages from the server. <br>
# Instead of only pulling 20 rows of data, we are able to pull 1000 rows of data (the maximum that the Ticketmaster Public API allows) and returning a dataframe. </p>

# %%
def getAllPages(pages=10, per_page=100):
    # url = f'https://app.ticketmaster.com/discovery/v2/events.json?apikey={API_KEY}'
    
    events_params_action_api = {
    'startDateTime': '2025-05-01T18:00:00-05:00',
    'endDateTime': '2027-12-31T17:00:00-05:00',
    'classificationName': 'music',
    # 'dmaId': '345', 
    'city': 'New York',
    'size': '200', 
    'page': '100'
    }
    
    all_records = []

    # url = f'https://app.ticketmaster.com/discovery/v2/events.json?countryCode=US&apikey={API_KEY}'
    url = f'https://app.ticketmaster.com/discovery/v2/events.json?apikey={API_KEY}'

    for page in range(1, pages + 1):         
        response = requests.get(
            url,
            params={**events_params_action_api, 'page': page, 'size': per_page}
        )
        response.raise_for_status()
        records = response.json()
        #(data['_embedded']['events'])
        all_records.extend(records['_embedded']['events'])
        
    return pd.DataFrame(all_records)

# %% [markdown]
# ### Created a variable `more_events` to call the pagination function `getAllPages()` ###

# %%
more_events= getAllPages()

# %%
renamed_more_events = more_events.rename(columns= {
    'name':'NAME', 
    'type': 'TYPE', 
    'id': 'ID',
    'classifications': 'GENRE', 
    'accessibility': 'ACCESSIBILITY', 
    'ticketLimit': 'TICKET_LIMIT', 
    '_embedded': 'VENUE_NAME',
    'products': 'PRODUCTS'
}
)

# %% [markdown]
# ##### <code>more_events.info</code>
# <p> When looking at the updated dataframe of 1000 rows, we see that there are some columns <br>
# that contain quite a significant amount of data such as <code>products</code>, <code>ticketLimit</code> and <code>accessibility</code>.

# %%
more_events.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 27 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1000 non-null   str
#  1   type             1000 non-null   str
#  2   id               1000 non-null   str
#  3   test             1000 non-null   bool
#  4   url              1000 non-null   str
#  5   locale           1000 non-null   str
#  6   images           1000 non-null   object
#  7   sales            1000 non-null   object
#  8   dates            1000 non-null   object
#  9   classifications  1000 non-null   object
#  10  promoter         465 non-null    object
#  11  promoters        465 non-null    object
#  12  info             648 non-null    str
#  13  pleaseNote       821 non-null    str
#  14  products         175 non-null    object
#  15  seatmap          377 non-null    object
#  16  accessibility    186 non-null    object
# ...

# %%
more_events
# Out:
#                                           name   type              id   test  \
# 0                               Alabama Shakes  event   G5dYZ_F-Hysua  False
# 1    Khalid: It's Always Summer Somewhere Tour  event   G5dYZbzhrO0M1  False
# 2             YUNGBLUD: IDOLS - THE WORLD TOUR  event   G5dYZbVkK6OTg  False
# 3             Jessie Ware: The Superbloom Tour  event   G5dYZ_kma1OTc  False
# 4              Mon Laferte - Femme Fatale Tour  event   G5dYZ_kppZOWi  False
# ..                                         ...    ...             ...    ...
# 995                               Step Afrika!  event   Z7r9jZ1A7xpG0  False
# 996                               Step Afrika!  event   Z7r9jZ1A7xpGb  False
# 997                               Step Afrika!  event   Z7r9jZ1A7xpGx  False
# 998                               Step Afrika!  event   Z7r9jZ1A7xpG9  False
# 999       The World Famous Harlem Gospel Choir  event  rZ7HnEZ1Af0yrd  False
#
# ...

# %% [markdown]
# ### Created `data_ex` variable to filter for columns that we don't need and renaming columns

# %%
data_ex = renamed_more_events.loc[:, ~renamed_more_events.columns.isin(['images','doorsTimes', '_links', 'linkMoreInfo', 'outlets', 'images', 'test','pleaseNote', 'seatmap','nameOrigin', 'promoters', 'url', 'priceRanges', 'locale', 'sales', 'dates','ageRestrictions'])]

# %%
# data_ex = more_events.loc[:, ~renamed_more_events.columns.isin(['images','doorsTimes', '_links', 'linkMoreInfo', 'outlets', 'images', 'test','pleaseNote', 'seatmap','nameOrigin', 'promoters', 'url', 'priceRanges', 'locale', 'sales', 'dates','ageRestrictions'])]

# %%
data_ex
# Out:
#                                           NAME   TYPE              ID  \
# 0                               Alabama Shakes  event   G5dYZ_F-Hysua
# 1    Khalid: It's Always Summer Somewhere Tour  event   G5dYZbzhrO0M1
# 2             YUNGBLUD: IDOLS - THE WORLD TOUR  event   G5dYZbVkK6OTg
# 3             Jessie Ware: The Superbloom Tour  event   G5dYZ_kma1OTc
# 4              Mon Laferte - Femme Fatale Tour  event   G5dYZ_kppZOWi
# ..                                         ...    ...             ...
# 995                               Step Afrika!  event   Z7r9jZ1A7xpG0
# 996                               Step Afrika!  event   Z7r9jZ1A7xpGb
# 997                               Step Afrika!  event   Z7r9jZ1A7xpGx
# 998                               Step Afrika!  event   Z7r9jZ1A7xpG9
# 999       The World Famous Harlem Gospel Choir  event  rZ7HnEZ1Af0yrd
#
#                                                  GENRE  \
# 0    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# ...

# %%
data_ex.rename(columns= {
    'name':'NAME', 
    'type': 'TYPE', 
    'id': 'ID',
    'classifications': 'GENRE', 
    'promoter': 'PROMOTER',
    'accessibility': 'ACCESSIBILITY', 
    'ticketLimit': 'TICKET_LIMIT', 
    '_embedded': 'VENUE_NAME',
    'products': 'PRODUCTS',
    'ticketLimit': 'TICKET_LIMIT',
    'info': 'INFO',
    'ticketing': 'TICKETING'


}, inplace=True
)

# %%
data_ex
# Out:
#                                           NAME   TYPE              ID  \
# 0                               Alabama Shakes  event   G5dYZ_F-Hysua
# 1    Khalid: It's Always Summer Somewhere Tour  event   G5dYZbzhrO0M1
# 2             YUNGBLUD: IDOLS - THE WORLD TOUR  event   G5dYZbVkK6OTg
# 3             Jessie Ware: The Superbloom Tour  event   G5dYZ_kma1OTc
# 4              Mon Laferte - Femme Fatale Tour  event   G5dYZ_kppZOWi
# ..                                         ...    ...             ...
# 995                               Step Afrika!  event   Z7r9jZ1A7xpG0
# 996                               Step Afrika!  event   Z7r9jZ1A7xpGb
# 997                               Step Afrika!  event   Z7r9jZ1A7xpGx
# 998                               Step Afrika!  event   Z7r9jZ1A7xpG9
# 999       The World Famous Harlem Gospel Choir  event  rZ7HnEZ1Af0yrd
#
#                                                  GENRE  \
# 0    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# ...

# %%
product_name = data_ex['PRODUCTS']

# %% [markdown]
# For the PRODUCTS column, we are missing 827 values out of 1000 rows.

# %%
print(data_ex['PRODUCTS'].isna().sum())
# Out:
# 825

# %% [markdown]
# ### This code which worked for the initial 20 rows of data, won't work for 1000 rows of data, since there's some missing products which results in NaN values. ###

# %%
# product_name = data_ex['products']
# for item in product_name:
#     for n in item:
#         print(n['name'])

# %%
product_name = n['name']

# %%
data_ex.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NAME           1000 non-null   str
#  1   TYPE           1000 non-null   str
#  2   ID             1000 non-null   str
#  3   GENRE          1000 non-null   object
#  4   PROMOTER       465 non-null    object
#  5   INFO           648 non-null    str
#  6   PRODUCTS       175 non-null    object
#  7   ACCESSIBILITY  186 non-null    object
#  8   TICKET_LIMIT   346 non-null    object
#  9   TICKETING      504 non-null    object
#  10  VENUE_NAME     1000 non-null   object
# dtypes: object(7), str(4)
# memory usage: 469.0+ KB

# %%
# accessibility_mode = data_ex['ACCESSIBILITY'].mode()
# data_ex['ACCESSIBILITY']=data_ex['ACCESSIBILITY'].fillna(accessibility_mode, inplace=True)

# %%
data_ex['ACCESSIBILITY']
# Out:
# 0      {'ticketLimit': 2}
# 1      {'ticketLimit': 2}
# 2      {'ticketLimit': 2}
# 3      {'ticketLimit': 2}
# 4      {'ticketLimit': 2}
#               ...
# 995                   NaN
# 996                   NaN
# 997                   NaN
# 998                   NaN
# 999                   NaN
# Name: ACCESSIBILITY, Length: 1000, dtype: object

# %%
data_ex
# Out:
#                                           NAME   TYPE              ID  \
# 0                               Alabama Shakes  event   G5dYZ_F-Hysua
# 1    Khalid: It's Always Summer Somewhere Tour  event   G5dYZbzhrO0M1
# 2             YUNGBLUD: IDOLS - THE WORLD TOUR  event   G5dYZbVkK6OTg
# 3             Jessie Ware: The Superbloom Tour  event   G5dYZ_kma1OTc
# 4              Mon Laferte - Femme Fatale Tour  event   G5dYZ_kppZOWi
# ..                                         ...    ...             ...
# 995                               Step Afrika!  event   Z7r9jZ1A7xpG0
# 996                               Step Afrika!  event   Z7r9jZ1A7xpGb
# 997                               Step Afrika!  event   Z7r9jZ1A7xpGx
# 998                               Step Afrika!  event   Z7r9jZ1A7xpG9
# 999       The World Famous Harlem Gospel Choir  event  rZ7HnEZ1Af0yrd
#
#                                                  GENRE  \
# 0    [{'primary': True, 'segment': {'id': 'KZFzniwn...
# ...

# %% [markdown]
# <p> We don't want to arbitrarily drop NAN values for the missing values in
# <code>Products</code>, <code>Accessibility</code>, <br><code>Genre</code> and
# <code>Venues</code> since this would introduce a bias due to the large
# number of missing values.
#
# <!-- #### Dropping NAN values for Products, Accessibility, Genre column, Venues Name column and making a copy while retaining original column values. ####  -->

# %%
data_ex.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   NAME           1000 non-null   str
#  1   TYPE           1000 non-null   str
#  2   ID             1000 non-null   str
#  3   GENRE          1000 non-null   object
#  4   PROMOTER       465 non-null    object
#  5   INFO           648 non-null    str
#  6   PRODUCTS       175 non-null    object
#  7   ACCESSIBILITY  186 non-null    object
#  8   TICKET_LIMIT   346 non-null    object
#  9   TICKETING      504 non-null    object
#  10  VENUE_NAME     1000 non-null   object
# dtypes: object(7), str(4)
# memory usage: 469.0+ KB

# %% [markdown]
# ##### For the <code>data_ex['PRODUCTS']</code>, we only have values for 173 rows out of 1000 (missing 827 rows of data). We are not able to take the mean since this column is categorical and fill in the NaN rows, so I'm not sure how else to resolve this.

# %%
data_ex['PRODUCTS']
# Out:
# 0      [{'name': 'SPOTHERO RADIO CITY MUSIC HALL', 'i...
# 1      [{'name': 'SPOTHERO RADIO CITY MUSIC HALL', 'i...
# 2      [{'name': 'SPOTHERO RADIO CITY MUSIC HALL', 'i...
# 3      [{'name': 'SPOTHERO RADIO CITY MUSIC HALL', 'i...
# 4      [{'name': 'SPOTHERO RADIO CITY MUSIC HALL', 'i...
#                              ...
# 995                                                  NaN
# 996                                                  NaN
# 997                                                  NaN
# 998                                                  NaN
# 999                                                  NaN
# Name: PRODUCTS, Length: 1000, dtype: object

# %%
data_clean = data_ex.dropna(subset = ['PRODUCTS', 'ACCESSIBILITY']).copy()

# %%
data_clean.rename(columns= {
    'name':'NAME', 
    'type': 'TYPE', 
    'id': 'ID',
    'classifications': 'GENRE', 
    'promoter': 'PROMOTER',
    'ticketLimit': 'TICKET_LIMIT', 
    '_embedded': 'VENUE_NAME',
    'ticketLimit': 'TICKET_LIMIT',
    'info': 'INFO',
    'products': 'PRODUCTS',
    'accessibility': 'ACCESSIBILITY',
    'ticketing': 'TICKETING' ,
    'Accessibility_Filtered': 'ACCESSIBILITY_Filtered'
    


}, inplace=True
)

# %% [markdown]
# #### List comprehension to create new dataframe after dropped NaN values to create new column for 'Products_Filtered' ####

# %%
# data_clean['PRODUCTS_Filtered'] = [
#     [n['name'] for n in item] for item in data_clean['PRODUCTS']
# ] #list of products name

data_clean['PRODUCTS_Filtered'] = [
    ', '.join([n['name'] for n in item]) for item in data_clean['PRODUCTS']
]
#converted list of products using comma separator

# %%
data_clean['VENUE_NAME_Filtered'] = [
    name['venues'][0]['name']
    for name in data_clean['VENUE_NAME']
    
    
]
data_clean['Accessibility_Filtered'] = [
    f"Ticket Limit: {item.get('ticketLimit', 'N/A')}" for item in data_clean['ACCESSIBILITY']
]


data_clean['Genre_Filtered'] = [item['genre']['name']
                                for x in data_clean['GENRE']
                                for item in x
    ]

# %% [markdown]
# #### Final Dataframe version ####

# %%
data_clean
# Out:
#                                                   NAME   TYPE             ID  \
# 0                                       Alabama Shakes  event  G5dYZ_F-Hysua
# 1            Khalid: It's Always Summer Somewhere Tour  event  G5dYZbzhrO0M1
# 2                     YUNGBLUD: IDOLS - THE WORLD TOUR  event  G5dYZbVkK6OTg
# 3                     Jessie Ware: The Superbloom Tour  event  G5dYZ_kma1OTc
# 4                      Mon Laferte - Femme Fatale Tour  event  G5dYZ_kppZOWi
# ..                                                 ...    ...            ...
# 541             Myriam Hernandez - Tauro Usa Tour 2026  event  k7vGFbzEbiDTb
# 669  Tribeca Festival Presents Sara Bareilles: Good...  event  G5diZ_FcMIo9S
# 671                                          Tony Vega  event  k7vGFbVrPcvA_
# 672                                La Dinastia Rosario  event  k7vGF_ddMZ_Ov
# 841                                               Luna  event  k7vGF_52RV_QK
#
# ...

# %% [markdown]
# ##### Reordering columns for **'Accessibility_Filtered', 'Products_Filtered', 'Genre_Filtered', 'VENUE_NAME_Filtered** to position them next to the original data. #####

# %%
move_col1=data_clean.pop('Accessibility_Filtered')
data_clean.insert(9, column='Accessibility_Filtered', value=move_col1)

move_col2 = data_clean.pop('Genre_Filtered')
data_clean.insert(4, column='Genre_Filtered', value=move_col2)

move_col3 = data_clean.pop('PROMOTER')
data_clean.insert(10, column='PROMOTER',value=move_col3 )

move_col4 = data_clean.pop('VENUE_NAME_Filtered')
data_clean.insert(6, column='VENUE_NAME_Filtered', value=move_col4)

move_col5 = data_clean.pop('INFO')
data_clean.insert(11, column='INFO', value=move_col5)

move_col6 = data_clean.pop('VENUE_NAME')
data_clean.insert(5, column='VENUE_NAME', value=move_col6)

move_col7 = data_clean.pop('PRODUCTS')
data_clean.insert(7, column='PRODUCTS', value=move_col7)

move_col8 = data_clean.pop('PRODUCTS_Filtered') #Not sure why 'Products_Filtered' appears two times. 
data_clean.insert(8, column='PRODUCTS_Filtered', value=move_col8)

# %% [markdown]
# #### Final Dataframe ####

# %%
data_clean.to_csv('data/processed/TicketMaster.csv')

# %%
data_clean.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 162 entries, 0 to 841
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   NAME                    162 non-null    str
#  1   TYPE                    162 non-null    str
#  2   ID                      162 non-null    str
#  3   GENRE                   162 non-null    object
#  4   Genre_Filtered          162 non-null    str
#  5   VENUE_NAME              162 non-null    object
#  6   VENUE_NAME_Filtered     162 non-null    str
#  7   PRODUCTS                162 non-null    object
#  8   PRODUCTS_Filtered       162 non-null    str
#  9   ACCESSIBILITY           162 non-null    object
#  10  TICKET_LIMIT            143 non-null    object
#  11  Accessibility_Filtered  162 non-null    str
#  12  PROMOTER                162 non-null    object
#  13  INFO                    141 non-null    str
#  14  TICKETING               162 non-null    object
# ...

# %% [markdown]
# ##### *Used AI-generated code for filtering* ####

# %%
data_clean['ACCESSIBILITY'].apply(lambda x: list(x.keys())).value_counts()
# Out:
# ACCESSIBILITY
# [ticketLimit]    159
# []                 3
# Name: count, dtype: int64

# %% [markdown]
# ### Code for looping inside Accessibility column and removing NaN values using list comprehension in data_clean dataframe ###

# %%
# data_clean['Accessibility_Filtered'] = [
#     f'Ticket Limit: {value}'
#     for item in accessibility
#     for location, value in item.items()]

print(data_ex['ACCESSIBILITY'].isna().sum())
# Out:
# 814

# %% [markdown]
# ### Using list comprehension in data_clean dataframe ###

# %%
for x in genre: #x is the dictionary
    for item in x:
        print(item['genre']['name']) 
        #loop through Genre list to pull Genre name.
# Out:
# Rock
# Rock
# R&B
# Rock
# Pop
# Rock
# Rock
# Country
# Latin
# R&B
# Latin
# Rock
# Rock
# Rock
# Country
# Country
# Rock
# Rock
# Rock
# Rock
